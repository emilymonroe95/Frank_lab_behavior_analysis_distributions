# %% [markdown]
# # EM analysis Experimenting

# %% [markdown]
# #### Run this at the beginning of every notebook

# %% [markdown]
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### importing data and reading in CSV

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv (r'/home/emonroe/Downloads/20210531_toEM/behavior_csv/chimi_clean_contingencies_only_parsed_data.csv')

# %% [markdown]
# #### pulling out only the first epoch of the first day, plus other experimenting code

# %%
#df.index = #RangeIndex(start=0, stop=10115, step=1)
#df.columns =Index([u'Unnamed: 0', u'leaf', u'stem', u'reward', u'contingency', u'date',
       #u'session', u'trial'],
     # dtype='object')
#df.columns[1] = leaf
# df.dtypes
# Unnamed: 0      int64
# leaf            int64
# stem           object
# reward          int64
# contingency     int64
# date            int64
# session         int64
# trial           int64
# dtype: object
firstday_firstsesh = df[(df['session'] == 1) & (df['date'] == 20200213)]
#first
firstday_firstsesh 
         # ->>> Uncomment above if you wanna see table
#okay so i finally figured out how to index and pull out only rows where col = specific things. 
#Made a plot of leaves visited but need to figure out how to add axis titles/beautify.
# Out:
#      Unnamed: 0  leaf stem  reward   contingency      date  session  trial
# 0             0     4    B       1  805020802050  20200213        1      0
# 1             1     3    B       1  805020802050  20200213        1      1
# 2             2     1    A       1  805020802050  20200213        1      2
# 3             3     2    A       0  805020802050  20200213        1      3
# 4             4     1    A       1  805020802050  20200213        1      4
# 5             5     6    C       1  805020802050  20200213        1      5
# 6             6     5    C       0  805020802050  20200213        1      6
# 7             7     6    C       1  805020802050  20200213        1      7
# 8             8     5    C       0  805020802050  20200213        1      8
# 9             9     3    B       0  805020802050  20200213        1      9
# 10           10     4    B       1  805020802050  20200213        1     10
# 11           11     3    B       0  805020802050  20200213        1     11
# 12           12     4    B       1  805020802050  20200213        1     12
# 13           13     3    B       0  805020802050  20200213        1     13
# 14           14     4    B       1  805020802050  20200213        1     14
# 15           15     6    C       0  805020802050  20200213        1     15
# 16           16     5    C       0  805020802050  20200213        1     16
# 17           17     6    C       0  805020802050  20200213        1     17
# 18           18     2    A       1  805020802050  20200213        1     18
# 19           19     1    A       0  805020802050  20200213        1     19
# 20           20     2    A       1  805020802050  20200213        1     20
# 21           21     4    B       1  805020802050  20200213        1     21
# 22           22     3    B       0  805020802050  20200213        1     22
# 23           23     4    B       1  805020802050  20200213        1     23
# 24           24     2    A       0  805020802050  20200213        1     24
# 25           25     1    A       0  805020802050  20200213        1     25
# 26           26     2    A       0  805020802050  20200213        1     26
# 27           27     1    A       1  805020802050  20200213        1     27
# 28           28     2    A       0  805020802050  20200213        1     28
# 29           29     3    B       0  805020802050  20200213        1     29
# ..          ...   ...  ...     ...           ...       ...      ...    ...
# 250         250     3    B       1  205080508020  20200213        1    250
# 251         251     4    B       0  205080508020  20200213        1    251
# 252         252     3    B       1  205080508020  20200213        1    252
# 253         253     4    B       0  205080508020  20200213        1    253
# 254         254     3    B       1  205080508020  20200213        1    254
# 255         255     4    B       1  205080508020  20200213        1    255
# 256         256     3    B       1  205080508020  20200213        1    256
# 257         257     4    B       1  205080508020  20200213        1    257
# 258         258     3    B       1  205080508020  20200213        1    258
# 259         259     4    B       1  205080508020  20200213        1    259
# 260         260     3    B       1  205080508020  20200213        1    260
# 261         261     4    B       1  205080508020  20200213        1    261
# 262         262     3    B       1  205080508020  20200213        1    262
# 263         263     4    B       0  205080508020  20200213        1    263
# 264         264     3    B       1  205080508020  20200213        1    264
# 265         265     4    B       1  205080508020  20200213        1    265
# 266         266     3    B       1  205080508020  20200213        1    266
# 267         267     4    B       0  205080508020  20200213        1    267
# 268         268     3    B       1  205080508020  20200213        1    268
# 269         269     4    B       1  205080508020  20200213        1    269
# 270         270     3    B       1  205080508020  20200213        1    270
# 271         271     4    B       1  205080508020  20200213        1    271
# 272         272     3    B       0  205080508020  20200213        1    272
# 273         273     4    B       0  205080508020  20200213        1    273
# 274         274     3    B       1  205080508020  20200213        1    274
# 275         275     4    B       1  205080508020  20200213        1    275
# 276         276     3    B       0  205080508020  20200213        1    276
# 277         277     4    B       0  205080508020  20200213        1    277
# 278         278     3    B       1  205080508020  20200213        1    278
# 279         279     4    B       0  205080508020  20200213        1    279
#
# [280 rows x 8 columns]

# %% [markdown]
# ## Plotting!

# %%
plt.scatter(firstday_firstsesh[firstday_firstsesh.columns[0]], firstday_firstsesh[firstday_firstsesh.columns[1]])
plt.title("visits to each leaf day1 epoch 1")
plt.xlabel("trial #")
plt.ylabel("leaf visited")
# Out:
# Text(0,0.5,'leaf visited')

# %%
# This cell will plot 2 things on top of eachother, plots a different way with ax
#figure, ax1 = plt.subplots() 
# ax1.plot(df[df.columns[0]],df[df.columns[1]],linewidth=0.5,zorder=1,label="Force1")
# #ax1.plot(df[df.columns[0]],df[df.columns[2]],linewidth=0.5,zorder=1, label = "Force2")

# %%
#This cell will currently plot all stems visited on every day, every epoch with X's
#plt.scatter(df[df.columns[0]], df[df.columns[1]], linewidth=.5, marker = "x" )

# %% [markdown]
# ### Finding how many trials spent at each stem

# %%
num_trials_A = firstday_firstsesh [(firstday_firstsesh['stem'] == 'A')]
num_trials_B = firstday_firstsesh [(firstday_firstsesh['stem'] == 'B')]
num_trials_C = firstday_firstsesh [(firstday_firstsesh['stem'] == 'C')]
A = len(num_trials_A)
B = len(num_trials_B)
C = len(num_trials_C)
print(A + B + C)
# Out:
# 280

# %%
stems = ['A', 'B', 'C']
visits = [A, B, C]
plt.bar(stems, visits)
plt.title('Num visits to each stem D1E1')
plt.xlabel('Stem')
plt.ylabel('num visits')
# Out:
# Text(0,0.5,'num visits')

# %% [markdown]
# ### Finding num rewards at each stem

# %%
num_rews_A = firstday_firstsesh [(firstday_firstsesh['reward'] == 1) & (firstday_firstsesh['stem'] == 'A')]
num_rews_B = firstday_firstsesh [(firstday_firstsesh['reward'] == 1) & (firstday_firstsesh['stem'] == 'B')]
num_rews_C = firstday_firstsesh [(firstday_firstsesh['reward'] == 1) & (firstday_firstsesh['stem'] == 'C')]
rA = len(num_rews_A)
rB = len(num_rews_B)
rC = len(num_rews_C)
print(rA + rB + rC)

stems = ['A', 'B', 'C']
rewards = [rA, rB, rC]
plt.bar(stems, rewards)
plt.title('Num rews at each stem D1E1')
plt.xlabel('Stem')
plt.ylabel('num rew')
# Out:
# 165
# Text(0,0.5,'num rew')

# %% [markdown]
# ### Playing with for loops

# %%
# A = []
# B = 0
# C = 0
# for i in range(len(firstday_firstsesh)):
#     #print(df.iloc[i,0], df.iloc[i,2])
#     if firstday_firstsesh.iloc[i,2] == 'A':
#         A[] = firstday_firstsesh[i,3]
                 
#          #A = A +1          
#     if firstday_firstsesh.iloc[i,2] == 'B':
#          B = B +1  
#     if firstday_firstsesh.iloc[i,2] == 'C':
#          C = C +1
# Out:
#   File "<ipython-input-246-6fc82ebb7109>", line 7
#     A[] = firstday_firstsesh[i,3]
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## rew rate calculation

# %% [markdown]
# ### rew rate all (rew) and only first part(rew_smaller) for plot

# %%
rew = firstday_firstsesh.iloc[ :, 3]
rew_smaller = firstday_firstsesh.iloc[ :100, 3]
#rew_all = firstday_firstsesh.iloc[]
rew_rate = rew_smaller.rolling(window=2).mean()
plt.plot(rew_rate, label = 'avg rew rate')
plt.plot(rew_smaller, 'rx', label = 'reward=binary')
plt.title("recent rew rate with rolling average, window=2")
plt.xlabel("trial")
plt.ylabel("Avg Rew Rate")
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
plt.rcParams["figure.figsize"] = (30,10)

# %% [markdown]
# ### Adding column of rew rate to firstday_firstsesh

# %%
rew_rate_all = rew.rolling(window=3).mean()
#rew_rate_all = pd.DataFrame(rew_rate_all)
firstday_firstsesh['Rew_rate'] = rew_rate_all
firstday_firstsesh
# Out:
# /home/emonroe/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Unnamed: 0  leaf stem  reward   contingency      date  session  trial  \
# 0             0     4    B       1  805020802050  20200213        1      0
# 1             1     3    B       1  805020802050  20200213        1      1
# 2             2     1    A       1  805020802050  20200213        1      2
# 3             3     2    A       0  805020802050  20200213        1      3
# 4             4     1    A       1  805020802050  20200213        1      4
# 5             5     6    C       1  805020802050  20200213        1      5
# 6             6     5    C       0  805020802050  20200213        1      6
# 7             7     6    C       1  805020802050  20200213        1      7
# 8             8     5    C       0  805020802050  20200213        1      8
# 9             9     3    B       0  805020802050  20200213        1      9
# 10           10     4    B       1  805020802050  20200213        1     10
# 11           11     3    B       0  805020802050  20200213        1     11
# 12           12     4    B       1  805020802050  20200213        1     12
# 13           13     3    B       0  805020802050  20200213        1     13
# 14           14     4    B       1  805020802050  20200213        1     14
# 15           15     6    C       0  805020802050  20200213        1     15
# 16           16     5    C       0  805020802050  20200213        1     16
# 17           17     6    C       0  805020802050  20200213        1     17
# 18           18     2    A       1  805020802050  20200213        1     18
# 19           19     1    A       0  805020802050  20200213        1     19
# 20           20     2    A       1  805020802050  20200213        1     20
# 21           21     4    B       1  805020802050  20200213        1     21
# 22           22     3    B       0  805020802050  20200213        1     22
# 23           23     4    B       1  805020802050  20200213        1     23
# 24           24     2    A       0  805020802050  20200213        1     24
# 25           25     1    A       0  805020802050  20200213        1     25
# 26           26     2    A       0  805020802050  20200213        1     26
# 27           27     1    A       1  805020802050  20200213        1     27
# 28           28     2    A       0  805020802050  20200213        1     28
# 29           29     3    B       0  805020802050  20200213        1     29
# ..          ...   ...  ...     ...           ...       ...      ...    ...
# 250         250     3    B       1  205080508020  20200213        1    250
# 251         251     4    B       0  205080508020  20200213        1    251
# 252         252     3    B       1  205080508020  20200213        1    252
# 253         253     4    B       0  205080508020  20200213        1    253
# 254         254     3    B       1  205080508020  20200213        1    254
# 255         255     4    B       1  205080508020  20200213        1    255
# 256         256     3    B       1  205080508020  20200213        1    256
# 257         257     4    B       1  205080508020  20200213        1    257
# 258         258     3    B       1  205080508020  20200213        1    258
# 259         259     4    B       1  205080508020  20200213        1    259
# 260         260     3    B       1  205080508020  20200213        1    260
# 261         261     4    B       1  205080508020  20200213        1    261
# 262         262     3    B       1  205080508020  20200213        1    262
# 263         263     4    B       0  205080508020  20200213        1    263
# 264         264     3    B       1  205080508020  20200213        1    264
# 265         265     4    B       1  205080508020  20200213        1    265
# 266         266     3    B       1  205080508020  20200213        1    266
# 267         267     4    B       0  205080508020  20200213        1    267
# 268         268     3    B       1  205080508020  20200213        1    268
# 269         269     4    B       1  205080508020  20200213        1    269
# 270         270     3    B       1  205080508020  20200213        1    270
# 271         271     4    B       1  205080508020  20200213        1    271
# 272         272     3    B       0  205080508020  20200213        1    272
# 273         273     4    B       0  205080508020  20200213        1    273
# 274         274     3    B       1  205080508020  20200213        1    274
# 275         275     4    B       1  205080508020  20200213        1    275
# 276         276     3    B       0  205080508020  20200213        1    276
# 277         277     4    B       0  205080508020  20200213        1    277
# 278         278     3    B       1  205080508020  20200213        1    278
# 279         279     4    B       0  205080508020  20200213        1    279
#
#      Rew_rate
# 0         NaN
# 1         NaN
# 2    1.000000
# 3    0.666667
# 4    0.666667
# 5    0.666667
# 6    0.666667
# 7    0.666667
# 8    0.333333
# 9    0.333333
# 10   0.333333
# 11   0.333333
# 12   0.666667
# 13   0.333333
# 14   0.666667
# 15   0.333333
# 16   0.333333
# 17   0.000000
# 18   0.333333
# 19   0.333333
# 20   0.666667
# 21   0.666667
# 22   0.666667
# 23   0.666667
# 24   0.333333
# 25   0.333333
# 26   0.000000
# 27   0.333333
# 28   0.333333
# 29   0.333333
# ..        ...
# 250  1.000000
# 251  0.666667
# 252  0.666667
# 253  0.333333
# 254  0.666667
# 255  0.666667
# 256  1.000000
# 257  1.000000
# 258  1.000000
# 259  1.000000
# 260  1.000000
# 261  1.000000
# 262  1.000000
# 263  0.666667
# 264  0.666667
# 265  0.666667
# 266  1.000000
# 267  0.666667
# 268  0.666667
# 269  0.666667
# 270  1.000000
# 271  1.000000
# 272  0.666667
# 273  0.333333
# 274  0.333333
# 275  0.666667
# 276  0.666667
# 277  0.333333
# 278  0.333333
# 279  0.333333
#
# [280 rows x 9 columns]

# %% [markdown]
# ### calculate rew rates @ each stem- i hate this

# %%
# rewA=[]
# for ix in range(len(firstday_firstsesh['stem'])):        
#     if firstday_firstsesh.iloc[ix,2] == 'A':
#         rewA[ix,:] = firstday_firstsesh.iloc[ix,3]
# rewA
#     elif firstday_firstsesh.iloc[ix, 2] == 'B':
#         rewB = firstday_firstsesh.iloc[ix, 3]
#         rew_rateB = rewB.rolling(window=2).mean()
#         firstday_firstsesh['Rew_rate_B'] = rew_rateB
#     elif firstday_firstsesh.iloc[ix, 2] == 'C':
#         rewC = firstday_firstsesh.iloc[ix, 3]
#         rew_rateC = rewC.rolling(window=2).mean()
#         firstday_firstsesh['Rew_rate_C'] = rew_rateC

        
rewA = firstday_firstsesh[(firstday_firstsesh['stem'] == 'A')]
rewA = rewA.iloc[ :, 3]
#rew_all = firstday_firstsesh.iloc[]
rew_rateA = rewA.rolling(window=2).mean()
#rew_rateA
#firstday_firstsesh['Rew_rate_A'] = rew_rateA


rewB = firstday_firstsesh[(firstday_firstsesh['stem'] == 'B')]
rewB = rewB.iloc[ :, 3]
#rew_all = firstday_firstsesh.iloc[]
rew_rateB = rewB.rolling(window=2).mean()
#rew_rateA
#firstday_firstsesh['Rew_rate_B'] = rew_rateB


rewC = firstday_firstsesh[(firstday_firstsesh['stem'] == 'C')]
rewC = rewC.iloc[ :, 3]
#rew_all = firstday_firstsesh.iloc[]
rew_rateC = rewC.rolling(window=2).mean()
#rew_rateA
#firstday_firstsesh['Rew_rate_C'] = rew_rateC
#firstday_firstsesh

plt.plot(rew_rateA, 'x', label = "rewRateA")
plt.plot(rew_rateB, 'x', label = "rewRateB")
plt.plot(rew_rateC, 'x', label = "rewRateC")

plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
plt.rcParams["figure.figsize"] = (20,10)
plt.title('Rew rate at each stem')
plt.xlabel('trial')
plt.ylabel('rew rate for each stem')
plt.legend(framealpha=1, frameon=True)

# %% [markdown]
# ## Splitting up contingenices, finding most rewarded

# %%
c1 = firstday_firstsesh[(firstday_firstsesh['contingency'] == '805020802050')]
c2 = firstday_firstsesh[(firstday_firstsesh['contingency'] == '205080508020')]
c2
