# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import statistics
from scipy.optimize import curve_fit
import math 
from scipy.stats import binom

# %%
#The binomial random variable represents the number of successes(r) in n 
#successive independent trials of a Bernoulli experiment.

# %%
n = 1000
n1= range(n)
r = 200
#p = r/n
p= .99
p1=np.arange(0, 1, .1)
ix1=.1

# %%
#Probability of achieving r success and n-r failure is :
ix1=.5
prob_lst4 = []
#for ix1 in range(len(p1)+1):
for ix in range(len(n1)+1):
    prob = (math.factorial(n) / ((math.factorial(n-ix))*math.factorial(ix))) * ((ix1**ix) * ((1-ix1)**(n-ix))) 
    prob_lst4.append(prob)

# %%
#Probability of achieving r success and n-r failure is :
# prob_lst = []
# for ix in range(len(n1)+1):
#     prob = (math.factorial(n) / ((math.factorial(n-ix))*math.factorial(ix))) * ((p**ix) * ((1-p)**(n-ix))) 
#     prob_lst.append(prob)

# %%
plt.plot(prob_lst)
plt.plot(prob_lst1)
plt.plot(prob_lst2)
plt.plot(prob_lst3)
plt.plot(prob_lst4)
plt.title(f'num trials = {n}, prob/bias = {ix1}, num successes = {r} ')
plt.xlabel(f'probability of this many successes with prob {ix1} \n in {n} trials ')
plt.ylabel('probability')
#plt.xticks(0,200)
#how likely each of outcome is if number of trial is n, with true underlying pro is p.
#every trial is a bernoulli, every bout is a binomial.
# Out:
# Text(0, 0.5, 'probability')

# %%
mean, var = binom.stats(n, p)

# %%
#just use the experienced probability, use the variance to know how likely that is the correct

# %%
num_trial = 4 #bernoulli is for 1, binomial is with lots of trials) 
num_trial1 = range(num_trial)
num_rew = 3
rewarded = range(num_rew) 
prob = num_rew/num_trial
prob_lst = []
for ix in range(len(num_trial1)+1):
    prob1 = (math.factorial(num_trial) / ((math.factorial(num_trial-ix))*math.factorial(ix))) * ((prob**ix) * ((1-prob)**(num_trial-ix))) 
    prob_lst.append(prob1)
prob_lst
plt.plot(prob_lst)
plt.title(f'num trials = {num_trial}, prob/bias = {prob}, num successes = {num_rew} ')
plt.xlabel(f'number successes with prob {prob} \n in {num_trial} trials ')
plt.ylabel('likelihood of occurance of that outcome')
#higher n -> less vriance 
#change n and keep p constant, and p constant and change n)
   #sliding window
# Out:
# Text(0, 0.5, 'likelihood of occurance of that outcome')

# %%
#pick a something to explain to AC on monday
#Bournoulli- can either be 0 or 1. every trial(flip, visit to well) is a bernoulli trial. 
#A bernoulli distribution is like the number of rewarded vs nonrewarded trials. 
num_trials = 10
num_rewards = 5
rew_trials= [1]*num_rewards
num_non_rew = num_trials - num_rewards
nr_trials = [0]*num_non_rew
plt.hist(num_rewards,num_non_rew)
# Out:
# (array([0., 0., 1., 0., 0.]),
#  array([4.5, 4.7, 4.9, 5.1, 5.3, 5.5]),
#  <BarContainer object of 5 artists>)

# %%
#Okay first thing I should do. 
#There are 100 trials. 
#vary whil keeping n the same. 
n=100
p=.5
success = 40
r_values= np.arange(0, 30, 1).tolist()

dist = [binom.pmf(r, n, p) for r in r_values ]
# plotting the graph 
plt.bar(r_values, dist)
plt.show()

# %%
n= 10
n_s = 1
p = .5
# for ix in range(1,n):
#     prob = (math.factorial(ix) / ((math.factorial(ix-n_s))*math.factorial(n_s))) * ((p**n_s) * ((1-p)**(ix-n_s))) 
#     prob_lst.append(prob)

for ix in range(1,n):
    dist = [binom.pmf(n_s, ix, p)]
    plt.plot(dist)
#dist

# %%
ix
# Out:
# 9

# %%
#want to make my own coin flip expt

# %%
#in a bernoulli distribution, its a 0 or 1. There is some probability p of getting that 0 or 1. 
#In 1 trial, the likihood of getting X =1 is p. The likelihood of getting X = 0 is 1-p. 
#possible outcomes (k) are 0 and 1. 
#if k = 1, pmf (f) = p. If k = 0, f = 1-p. 
#in total, distribution = p^k * (1-p)^(1-k)
#so if k=0, f=1-p. If k=1, f=p. 

# a pmf is the probability that the random variable value is exactly equal to the real value. 
k=1
p = .6
f = (p**k) * (1-p)**(1-k)
f
p_1 = f
p_0 = 1-f
plt.scatter(0,p_0)
plt.scatter(1,p_1)
plt.title('bernoulli distribution with p=.6 \n the chance of getting a 1 is .6, chance of 0 is .4')
#since theres only1 trial,
# Out:
# Text(0.5, 1.0, 'bernoulli distribution with p=.6 \n the chance of getting a 1 is .6, chance of 0 is .4')

# %%
#now were going to do a bunch of bernoulli trials. (the binomial is just the sum of many bernoulli trials)
#in the coin flip example, if the probability is .6
#If I did 10 coin flips, maybe ill get 6 heads. But since its also random, I might also get 4 or 7 heads, or less
#likely, 3 or 8, etc. 
#But the more times I do this experiment of 10 coing flips, the more times I will get 6 heds, along with the more times 
#I will get other values, just due to randomness. 
#changing the probability/bias of the coin will shift the distribution from left to right (0,1)
#changing the number of trials will stretch the plot out.. 
#for example, if I only flipped the coin once, I would get a heads or tails, not very informative about the bias of the coin 
#lets just start with 2 trials.

# %%
binom_lst = []
n = 10000
s=5
p = .4
for ix in range(1,100000):
    binom_lst.append(np.random.binomial(n, p))
#[binom.pmf(s,n, p)]
plt.hist(binom_lst)
plt.title('number of times outcome occured with\n p =.4, n=10, number of repeats=1000' )
# Out:
# Text(0.5, 1.0, 'number of times outcome occured with\n p =.4, n=10, number of repeats=1000')

# %%
# Out:
# (array([  2.,  13.,  41., 115., 190., 264., 234.,  98.,  41.,   1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import binom
# setting the values
# of n and p
n = range(10)
p = 0.8
p1=.2
# defining the list of r values
#r_values = list(range(n + 1))
# obtaining the mean and variance 
# list of pmf values
for ix in n:
    r_values = list(range(ix + 1))
    mean, var = binom.stats(ix, p)
    dist = [binom.pmf(r, ix, p) for r in r_values ]
    plt.bar(r_values, dist)
    mean, var = binom.stats(ix, p1)
    dist1 = [binom.pmf(r, ix, p1) for r in r_values ]
    plt.bar(r_values, dist1)
    plt.title(f'binomial distribution with {n} trials and prob = {p} ')
    plt.xlabel('number of successes')
    plt.ylabel('likelihood of getting that many successes')
    plt.show()
# printing the table
print("r\tp(r)")
# for i in range(n + 1):
#     print(str(r_values[i]) + "\t" + str(dist[i]))
# printing mean and variance
# print("mean = "+str(mean))
# print("variance = "+str(var))
# plt.bar(r_values, dist)
# plt.title(f'binomial distribution with {n} trials and prob = {p} ')
# plt.xlabel('number of successes')
# plt.ylabel('likelihood of getting that many successes')
# plt.show()
# Out:
# r	p(r)

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Input variables
# Number of trials
trials = 100
# Number of independent experiments in each trial
n = 100
# Probability of success for each experiment
p = 0.75
# Function that runs our coin toss trials
# heads is a list of the number of successes from each trial of n experiments
# n1 = 10
#n1= 9
p1=(7/11)
#n2= 7
p2 = (2/7)


# def run_binom(trials, n, p):
#     heads = []
#     for i in range(trials):
#         tosses = [np.random.random() for i in range(n)]
#         heads.append(len([i for i in tosses if i>=0.50]))
#     return heads
# # Run the function
# heads = run_binom(trials, n, p)
# # Plot the results as a histogram
# fig, ax = plt.subplots(figsize=(14,7))
# #ax = sns.distplot(heads, bins=11, label='simulation results')
# ax.set_xlabel("Number of Heads",fontsize=16)
# ax.set_ylabel("Frequency",fontsize=16)
# ax.set_title(f'red=A, blue = C, purple=B')
# from scipy.stats import binom
x = range(0,n)
x1=range(0,n1)
x2=range(0,n2)

fig, ax = plt.subplots(figsize=(14,7))
#ax = sns.distplot(heads, bins=11, label='simulation results')
ax.set_xlabel("Number of Heads",fontsize=16)
ax.set_ylabel("Frequency",fontsize=16)
ax.set_title(f'red=A, blue = C, purple=B')
ax.plot(x, binom.pmf(x, n, p), 'ro', label='actual binomial distribution')
ax.vlines(x, 0, binom.pmf(x, n, p), colors='r', lw=5, alpha=0.5)

# fig, ax = plt.subplots(figsize=(14,7))
# #ax = sns.distplot(heads, bins=11, label='simulation results')
# ax.set_xlabel("Number of Heads",fontsize=16)
# ax.set_ylabel("Frequency",fontsize=16)
# ax.set_title(f'actual distributions with {n1} trials, {p1} prob')
ax.plot(x, binom.pmf(x, n, p1), 'ro', label='actual binomial distribution')
ax.vlines(x, 0, binom.pmf(x, n, p1), colors='b', lw=5, alpha=0.5)

# fig, ax = plt.subplots(figsize=(14,7))
# #ax = sns.distplot(heads, bins=11, label='simulation results')
# ax.set_xlabel("Number of Heads",fontsize=16)
# ax.set_ylabel("Frequency",fontsize=16)
# ax.set_title(f'actual distributions with {n2} trials, {p2} prob')
ax.plot(x, binom.pmf(x, n, p2), 'ro', label='actual binomial distribution')
ax.vlines(x, 0, binom.pmf(x, n, p2), colors='g', lw=5, alpha=0.5)
#plt.legend()
plt.show()
###############


# def run_binom(trials, n1, p1):
#     heads = []
#     for i in range(trials):
#         tosses = [np.random.random() for i in range(n)]
#         heads.append(len([i for i in tosses if i>=0.50]))
#     return heads
# # Run the function
# heads = run_binom(trials, n1, p1)
# # Plot the results as a histogram
# fig, ax = plt.subplots(figsize=(14,7))
# ax = sns.distplot(heads, bins=11, label='simulation results')
# ax.set_xlabel("Number of Heads",fontsize=16)
# ax.set_ylabel("Frequency",fontsize=16)
# ax.set_title(f'number of heads and tails with {n1} trials, {trials} experiments, {p1} prob')

# %%
np.random.binomial(n, p)
# Out:
# 8

# %%
# Probability of getting 6 heads
runs = 10000
prob_6 = sum([1 for i in np.random.binomial(n, p, size=runs) if i==8])/runs
print('The probability of 8 heads is: ' + str(prob_6))
# Out:
# The probability of 8 heads is: 0.3033

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Input variables
# Number of trials
trials = 1000
# Number of independent experiments in each trial
n = 10
# Probability of success for each experiment
p = 0.9
# Function that runs our coin toss trials
# heads is a list of the number of successes from each trial of n experiments
def run_binom(trials, n, p):
    heads = []
    for i in range(trials):
        tosses = [np.random.random() for i in range(n)]
        heads.append(len([i for i in tosses if i>=0.20]))
    return heads
# Run the function
heads = run_binom(trials, n, p)
# Plot the results as a histogram
fig, ax = plt.subplots(figsize=(14,7))
ax = sns.distplot(heads, bins=11, label='simulation results')
ax.set_xlabel("Number of Heads",fontsize=16)
ax.set_ylabel("Frequency",fontsize=16)
# Out:
# /home/emonroe/miniconda2/envs/Analysis_EM/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
from scipy.stats import binom
x = range(0,11)
ax.plot(x, binom.pmf(x, n, p), 'ro', label='actual binomial distribution')
ax.vlines(x, 0, binom.pmf(x, n, p), colors='r', lw=5, alpha=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ebd16855f48> in <module>
#       1 from scipy.stats import binom
#       2 x = range(0,11)
# ----> 3 ax.plot(x, binom.pmf(x, n, p), 'ro', label='actual binomial distribution')
#       4 ax.vlines(x, 0, binom.pmf(x, n, p), colors='r', lw=5, alpha=0.5)
#       5 plt.legend()
#
# NameError: name 'ax' is not defined
